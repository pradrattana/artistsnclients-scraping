# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\BB All\Work2021\AiBuilder\web_scraping\web_scraping_unclean.csv")
df
# Out:
#                                                  img url             img path  \
# 0      https://d9jhi50qo719s.cloudfront.net/jj3/sampl...     anime/img-0.jpeg
# 1      https://d9jhi50qo719s.cloudfront.net/ng1/sampl...      anime/img-1.jpg
# 2      https://d9jhi50qo719s.cloudfront.net/j4t/sampl...      anime/img-2.jpg
# 3      https://d9jhi50qo719s.cloudfront.net/13lf/samp...      anime/img-3.jpg
# 4      https://d9jhi50qo719s.cloudfront.net/1gen/samp...      anime/img-4.jpg
# ...                                                  ...                  ...
# 10689  https://d9jhi50qo719s.cloudfront.net/jx5/sampl...  anime/img-10897.jpg
# 10690  https://d9jhi50qo719s.cloudfront.net/1eim/samp...  anime/img-10898.png
# 10691  https://d9jhi50qo719s.cloudfront.net/euu/sampl...  anime/img-10899.png
# 10692  https://d9jhi50qo719s.cloudfront.net/1bbe/samp...  anime/img-10900.gif
# 10693                                                NaN                  NaN
#
# ...

# %%
df['price ($)'].plot.hist(edgecolor='k', bins=np.arange(0.5, 101, 5))
plt.xticks(np.arange(0.5, 101, 10))
plt.xlabel('price ($)')
# Out:
# Text(0.5, 0, 'price ($)')
